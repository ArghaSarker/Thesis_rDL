# %%
import datetime
import ipykernel
from csbdeep.io import load_training_data
from csbdeep.utils import axes_dict, plot_some,plot_history
import matplotlib.pyplot as plt
from actin_tubules_sim.models import DFCAN
from actin_tubules_sim.loss import mse_ssim
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import callbacks

# %%
root_dir = r'Z:\FDM-Common\ASarker\thesis\Microtubules'
train_data_file = f'{root_dir}/Train/SR/microtubule_sr_training_data.npz'
log_dir = "logs/fitSR/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
(X,Y), (X_val,Y_val), axes = load_training_data(train_data_file, validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
X = tf.squeeze(X, axis=-1)
X_val = tf.squeeze(X_val, axis=-1)
Y = tf.squeeze(Y, axis=-1)
Y_val = tf.squeeze(Y_val, axis=-1)
X = tf.transpose(X, perm=[0, 2, 3, 1])
X_val = tf.transpose(X_val, perm=[0, 2, 3, 1])

Y = tf.transpose(Y, perm=[0, 2, 3, 1])

Y_val = tf.transpose(Y_val, perm=[0, 2, 3, 1])
# Out:
# number of training images:	 486
# number of validation images:	 54
# image size (3D):		 (9, 128, 128)
# axes:				 SZYXC
# channels in / out:		 1 / 1

# %%
X.shape,Y.shape,X_val.shape
# Out:
# (TensorShape([486, 128, 128, 9]),
#  TensorShape([486, 256, 256, 1]),
#  TensorShape([54, 128, 128, 9]))

# %%
# %matplotlib inline
plt.figure(figsize=(12,5))
plot_some(tf.transpose(X_val[:5], perm=[0, 3, 1, 2]),Y_val[:5])
plt.suptitle('5 example validation patches (top row: source, bottom row: target)')

# %%
init_lr = 1e-4
batch_size = 3
epochs = 10
beta_1=0.9
beta_2=0.999
scale_gt = 2.0

total_data,  height, width, channels= X.shape

# %%
Trainingmodel = DFCAN((height, width, channels), scale=scale_gt)
optimizer = Adam(learning_rate=init_lr, beta_1=beta_1, beta_2=beta_2)
Trainingmodel.compile(loss=mse_ssim, optimizer=optimizer)
Trainingmodel.summary()

tensorboard_callback = callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
lrate = callbacks.ReduceLROnPlateau(monitor='loss', factor=0.1, patience=4, verbose=1)
hrate = callbacks.History()
# Out:
# (None, 128, 128, 9)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Tensor("Placeholder:0", shape=(None, 128, 128, 256), dtype=float32),2.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 9)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 64)         5248      ['input_1[0][0]']
#
#  lambda (Lambda)             (None, 128, 128, 64)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)         36928     ['lambda[0][0]']
#
#  lambda_1 (Lambda)           (None, 128, 128, 64)         0         ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)         36928     ['lambda_1[0][0]']
#
#  lambda_2 (Lambda)           (None, 128, 128, 64)         0         ['conv2d_2[0][0]']
#
#  lambda_3 (Lambda)           (None, 128, 128, 64)         0         ['lambda_2[0][0]']
#
#  lambda_4 (Lambda)           (None, 128, 128, 64)         0         ['lambda_3[0][0]']
#
#  tf.math.abs (TFOpLambda)    (None, 128, 128, 64)         0         ['lambda_4[0][0]']
#
#  tf.cast (TFOpLambda)        (None, 128, 128, 64)         0         ['tf.math.abs[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)         36928     ['tf.cast[0][0]']
#
#  lambda_5 (Lambda)           (None, 1, 1, 64)             0         ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 4)              260       ['lambda_5[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 64)             320       ['conv2d_4[0][0]']
#
#  multiply (Multiply)         (None, 128, 128, 64)         0         ['lambda_2[0][0]',
#                                                                      'conv2d_5[0][0]']
#
#  add (Add)                   (None, 128, 128, 64)         0         ['multiply[0][0]',
#                                                                      'lambda[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)         36928     ['add[0][0]']
#
#  lambda_6 (Lambda)           (None, 128, 128, 64)         0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 64)         36928     ['lambda_6[0][0]']
#
#  lambda_7 (Lambda)           (None, 128, 128, 64)         0         ['conv2d_7[0][0]']
#
#  lambda_8 (Lambda)           (None, 128, 128, 64)         0         ['lambda_7[0][0]']
#
#  lambda_9 (Lambda)           (None, 128, 128, 64)         0         ['lambda_8[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_9[0][0]']
#
#  tf.cast_1 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 64)         36928     ['tf.cast_1[0][0]']
#
#  lambda_10 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 1, 1, 4)              260       ['lambda_10[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_9[0][0]']
#
#  multiply_1 (Multiply)       (None, 128, 128, 64)         0         ['lambda_7[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  add_1 (Add)                 (None, 128, 128, 64)         0         ['multiply_1[0][0]',
#                                                                      'add[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 64)         36928     ['add_1[0][0]']
#
#  lambda_11 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_11[0][0]']
#
#  lambda_12 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_12[0][0]']
#
#  lambda_13 (Lambda)          (None, 128, 128, 64)         0         ['lambda_12[0][0]']
#
#  lambda_14 (Lambda)          (None, 128, 128, 64)         0         ['lambda_13[0][0]']
#
#  tf.math.abs_2 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_14[0][0]']
#
#  tf.cast_2 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_2[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_2[0][0]']
#
#  lambda_15 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_15[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_14[0][0]']
#
#  multiply_2 (Multiply)       (None, 128, 128, 64)         0         ['lambda_12[0][0]',
#                                                                      'conv2d_15[0][0]']
#
#  add_2 (Add)                 (None, 128, 128, 64)         0         ['multiply_2[0][0]',
#                                                                      'add_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 64)         36928     ['add_2[0][0]']
#
#  lambda_16 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_16[0][0]']
#
#  lambda_17 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_17[0][0]']
#
#  lambda_18 (Lambda)          (None, 128, 128, 64)         0         ['lambda_17[0][0]']
#
#  lambda_19 (Lambda)          (None, 128, 128, 64)         0         ['lambda_18[0][0]']
#
#  tf.math.abs_3 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_19[0][0]']
#
#  tf.cast_3 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_3[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_3[0][0]']
#
#  lambda_20 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_20[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_19[0][0]']
#
#  multiply_3 (Multiply)       (None, 128, 128, 64)         0         ['lambda_17[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  add_3 (Add)                 (None, 128, 128, 64)         0         ['multiply_3[0][0]',
#                                                                      'add_2[0][0]']
#
#  add_4 (Add)                 (None, 128, 128, 64)         0         ['add_3[0][0]',
#                                                                      'lambda[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 64)         36928     ['add_4[0][0]']
#
#  lambda_21 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_21[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_21[0][0]']
#
#  lambda_22 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_22[0][0]']
#
#  lambda_23 (Lambda)          (None, 128, 128, 64)         0         ['lambda_22[0][0]']
#
#  lambda_24 (Lambda)          (None, 128, 128, 64)         0         ['lambda_23[0][0]']
#
#  tf.math.abs_4 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_24[0][0]']
#
#  tf.cast_4 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_4[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_4[0][0]']
#
#  lambda_25 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_25[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_24[0][0]']
#
#  multiply_4 (Multiply)       (None, 128, 128, 64)         0         ['lambda_22[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  add_5 (Add)                 (None, 128, 128, 64)         0         ['multiply_4[0][0]',
#                                                                      'add_4[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 128, 128, 64)         36928     ['add_5[0][0]']
#
#  lambda_26 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_26[0][0]']
#
#  lambda_27 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_27[0][0]']
#
#  lambda_28 (Lambda)          (None, 128, 128, 64)         0         ['lambda_27[0][0]']
#
#  lambda_29 (Lambda)          (None, 128, 128, 64)         0         ['lambda_28[0][0]']
#
#  tf.math.abs_5 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_29[0][0]']
#
#  tf.cast_5 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_5[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_5[0][0]']
#
#  lambda_30 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_30[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_29[0][0]']
#
#  multiply_5 (Multiply)       (None, 128, 128, 64)         0         ['lambda_27[0][0]',
#                                                                      'conv2d_30[0][0]']
#
#  add_6 (Add)                 (None, 128, 128, 64)         0         ['multiply_5[0][0]',
#                                                                      'add_5[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 128, 128, 64)         36928     ['add_6[0][0]']
#
#  lambda_31 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_31[0][0]']
#
#  lambda_32 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_32[0][0]']
#
#  lambda_33 (Lambda)          (None, 128, 128, 64)         0         ['lambda_32[0][0]']
#
#  lambda_34 (Lambda)          (None, 128, 128, 64)         0         ['lambda_33[0][0]']
#
#  tf.math.abs_6 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_34[0][0]']
#
#  tf.cast_6 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_6[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_6[0][0]']
#
#  lambda_35 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_35[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_34[0][0]']
#
#  multiply_6 (Multiply)       (None, 128, 128, 64)         0         ['lambda_32[0][0]',
#                                                                      'conv2d_35[0][0]']
#
#  add_7 (Add)                 (None, 128, 128, 64)         0         ['multiply_6[0][0]',
#                                                                      'add_6[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 128, 128, 64)         36928     ['add_7[0][0]']
#
#  lambda_36 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_36[0][0]']
#
#  lambda_37 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_37[0][0]']
#
#  lambda_38 (Lambda)          (None, 128, 128, 64)         0         ['lambda_37[0][0]']
#
#  lambda_39 (Lambda)          (None, 128, 128, 64)         0         ['lambda_38[0][0]']
#
#  tf.math.abs_7 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_39[0][0]']
#
#  tf.cast_7 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_7[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_7[0][0]']
#
#  lambda_40 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_40[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_39[0][0]']
#
#  multiply_7 (Multiply)       (None, 128, 128, 64)         0         ['lambda_37[0][0]',
#                                                                      'conv2d_40[0][0]']
#
#  add_8 (Add)                 (None, 128, 128, 64)         0         ['multiply_7[0][0]',
#                                                                      'add_7[0][0]']
#
#  add_9 (Add)                 (None, 128, 128, 64)         0         ['add_8[0][0]',
#                                                                      'add_4[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 128, 128, 64)         36928     ['add_9[0][0]']
#
#  lambda_41 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_41[0][0]']
#
#  lambda_42 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_42[0][0]']
#
#  lambda_43 (Lambda)          (None, 128, 128, 64)         0         ['lambda_42[0][0]']
#
#  lambda_44 (Lambda)          (None, 128, 128, 64)         0         ['lambda_43[0][0]']
#
#  tf.math.abs_8 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_44[0][0]']
#
#  tf.cast_8 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_8[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_8[0][0]']
#
#  lambda_45 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_45[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_44[0][0]']
#
#  multiply_8 (Multiply)       (None, 128, 128, 64)         0         ['lambda_42[0][0]',
#                                                                      'conv2d_45[0][0]']
#
#  add_10 (Add)                (None, 128, 128, 64)         0         ['multiply_8[0][0]',
#                                                                      'add_9[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 128, 128, 64)         36928     ['add_10[0][0]']
#
#  lambda_46 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_46[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_46[0][0]']
#
#  lambda_47 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_47[0][0]']
#
#  lambda_48 (Lambda)          (None, 128, 128, 64)         0         ['lambda_47[0][0]']
#
#  lambda_49 (Lambda)          (None, 128, 128, 64)         0         ['lambda_48[0][0]']
#
#  tf.math.abs_9 (TFOpLambda)  (None, 128, 128, 64)         0         ['lambda_49[0][0]']
#
#  tf.cast_9 (TFOpLambda)      (None, 128, 128, 64)         0         ['tf.math.abs_9[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_9[0][0]']
#
#  lambda_50 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_48[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_50[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_49[0][0]']
#
#  multiply_9 (Multiply)       (None, 128, 128, 64)         0         ['lambda_47[0][0]',
#                                                                      'conv2d_50[0][0]']
#
#  add_11 (Add)                (None, 128, 128, 64)         0         ['multiply_9[0][0]',
#                                                                      'add_10[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 128, 128, 64)         36928     ['add_11[0][0]']
#
#  lambda_51 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_51[0][0]']
#
#  lambda_52 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_52[0][0]']
#
#  lambda_53 (Lambda)          (None, 128, 128, 64)         0         ['lambda_52[0][0]']
#
#  lambda_54 (Lambda)          (None, 128, 128, 64)         0         ['lambda_53[0][0]']
#
#  tf.math.abs_10 (TFOpLambda  (None, 128, 128, 64)         0         ['lambda_54[0][0]']
#  )
#
#  tf.cast_10 (TFOpLambda)     (None, 128, 128, 64)         0         ['tf.math.abs_10[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_10[0][0]']
#
#  lambda_55 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_53[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_55[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_54[0][0]']
#
#  multiply_10 (Multiply)      (None, 128, 128, 64)         0         ['lambda_52[0][0]',
#                                                                      'conv2d_55[0][0]']
#
#  add_12 (Add)                (None, 128, 128, 64)         0         ['multiply_10[0][0]',
#                                                                      'add_11[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 128, 128, 64)         36928     ['add_12[0][0]']
#
#  lambda_56 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_56[0][0]']
#
#  lambda_57 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_57[0][0]']
#
#  lambda_58 (Lambda)          (None, 128, 128, 64)         0         ['lambda_57[0][0]']
#
#  lambda_59 (Lambda)          (None, 128, 128, 64)         0         ['lambda_58[0][0]']
#
#  tf.math.abs_11 (TFOpLambda  (None, 128, 128, 64)         0         ['lambda_59[0][0]']
#  )
#
#  tf.cast_11 (TFOpLambda)     (None, 128, 128, 64)         0         ['tf.math.abs_11[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_11[0][0]']
#
#  lambda_60 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_58[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_60[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_59[0][0]']
#
#  multiply_11 (Multiply)      (None, 128, 128, 64)         0         ['lambda_57[0][0]',
#                                                                      'conv2d_60[0][0]']
#
#  add_13 (Add)                (None, 128, 128, 64)         0         ['multiply_11[0][0]',
#                                                                      'add_12[0][0]']
#
#  add_14 (Add)                (None, 128, 128, 64)         0         ['add_13[0][0]',
#                                                                      'add_9[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 128, 128, 64)         36928     ['add_14[0][0]']
#
#  lambda_61 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_61[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_61[0][0]']
#
#  lambda_62 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_62[0][0]']
#
#  lambda_63 (Lambda)          (None, 128, 128, 64)         0         ['lambda_62[0][0]']
#
#  lambda_64 (Lambda)          (None, 128, 128, 64)         0         ['lambda_63[0][0]']
#
#  tf.math.abs_12 (TFOpLambda  (None, 128, 128, 64)         0         ['lambda_64[0][0]']
#  )
#
#  tf.cast_12 (TFOpLambda)     (None, 128, 128, 64)         0         ['tf.math.abs_12[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_12[0][0]']
#
#  lambda_65 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_65[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_64[0][0]']
#
#  multiply_12 (Multiply)      (None, 128, 128, 64)         0         ['lambda_62[0][0]',
#                                                                      'conv2d_65[0][0]']
#
#  add_15 (Add)                (None, 128, 128, 64)         0         ['multiply_12[0][0]',
#                                                                      'add_14[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 128, 128, 64)         36928     ['add_15[0][0]']
#
#  lambda_66 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_66[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_66[0][0]']
#
#  lambda_67 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_67[0][0]']
#
#  lambda_68 (Lambda)          (None, 128, 128, 64)         0         ['lambda_67[0][0]']
#
#  lambda_69 (Lambda)          (None, 128, 128, 64)         0         ['lambda_68[0][0]']
#
#  tf.math.abs_13 (TFOpLambda  (None, 128, 128, 64)         0         ['lambda_69[0][0]']
#  )
#
#  tf.cast_13 (TFOpLambda)     (None, 128, 128, 64)         0         ['tf.math.abs_13[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_13[0][0]']
#
#  lambda_70 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_70[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_69[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 64)         0         ['lambda_67[0][0]',
#                                                                      'conv2d_70[0][0]']
#
#  add_16 (Add)                (None, 128, 128, 64)         0         ['multiply_13[0][0]',
#                                                                      'add_15[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 128, 128, 64)         36928     ['add_16[0][0]']
#
#  lambda_71 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_71[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_71[0][0]']
#
#  lambda_72 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_72[0][0]']
#
#  lambda_73 (Lambda)          (None, 128, 128, 64)         0         ['lambda_72[0][0]']
#
#  lambda_74 (Lambda)          (None, 128, 128, 64)         0         ['lambda_73[0][0]']
#
#  tf.math.abs_14 (TFOpLambda  (None, 128, 128, 64)         0         ['lambda_74[0][0]']
#  )
#
#  tf.cast_14 (TFOpLambda)     (None, 128, 128, 64)         0         ['tf.math.abs_14[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_14[0][0]']
#
#  lambda_75 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_73[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_75[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_74[0][0]']
#
#  multiply_14 (Multiply)      (None, 128, 128, 64)         0         ['lambda_72[0][0]',
#                                                                      'conv2d_75[0][0]']
#
#  add_17 (Add)                (None, 128, 128, 64)         0         ['multiply_14[0][0]',
#                                                                      'add_16[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 128, 128, 64)         36928     ['add_17[0][0]']
#
#  lambda_76 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_76[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 128, 128, 64)         36928     ['lambda_76[0][0]']
#
#  lambda_77 (Lambda)          (None, 128, 128, 64)         0         ['conv2d_77[0][0]']
#
#  lambda_78 (Lambda)          (None, 128, 128, 64)         0         ['lambda_77[0][0]']
#
#  lambda_79 (Lambda)          (None, 128, 128, 64)         0         ['lambda_78[0][0]']
#
#  tf.math.abs_15 (TFOpLambda  (None, 128, 128, 64)         0         ['lambda_79[0][0]']
#  )
#
#  tf.cast_15 (TFOpLambda)     (None, 128, 128, 64)         0         ['tf.math.abs_15[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 128, 128, 64)         36928     ['tf.cast_15[0][0]']
#
#  lambda_80 (Lambda)          (None, 1, 1, 64)             0         ['conv2d_78[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 1, 1, 4)              260       ['lambda_80[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_79[0][0]']
#
#  multiply_15 (Multiply)      (None, 128, 128, 64)         0         ['lambda_77[0][0]',
#                                                                      'conv2d_80[0][0]']
#
#  add_18 (Add)                (None, 128, 128, 64)         0         ['multiply_15[0][0]',
#                                                                      'add_17[0][0]']
#
#  add_19 (Add)                (None, 128, 128, 64)         0         ['add_18[0][0]',
#                                                                      'add_14[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 128, 128, 256)        147712    ['add_19[0][0]']
#
#  lambda_81 (Lambda)          (None, 128, 128, 256)        0         ['conv2d_81[0][0]']
#
#  lambda_82 (Lambda)          (None, 256, 256, 64)         0         ['lambda_81[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 256, 256, 1)          577       ['lambda_82[0][0]']
#
#  activation (Activation)     (None, 256, 256, 1)          0         ['conv2d_82[0][0]']
#
# ==================================================================================================
# Total params: 1935361 (7.38 MB)
# Trainable params: 1935361 (7.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training
# Training the model will likely take some time. We recommend to monitor the progress with [TensorBoard](https://www.tensorflow.org/programmers_guide/summaries_and_tensorboard), which allows you to inspect the losses during training.
#
# You can start TensorBoard from the current working directory with `tensorboard --logdir=.` Then connect to http://localhost:6006/ with your browser.

# %%
history = Trainingmodel.fit(X, Y, batch_size=batch_size,
                               epochs=epochs, validation_data=(X_val, Y_val), shuffle=True,
                               callbacks=[lrate, hrate, tensorboard_callback])
# Out:
# Epoch 1/10
# Tensor("model/lambda_81/mul_1:0", shape=(3, 128, 128, 256), dtype=float32),2.0
# Tensor("model/lambda_81/mul_1:0", shape=(3, 128, 128, 256), dtype=float32),2.0
# 165/165 [==============================] - ETA: 0s - loss: 0.0940Tensor("model/lambda_81/mul_1:0", shape=(None, 128, 128, 256), dtype=float32),2.0
# 165/165 [==============================] - 1299s 8s/step - loss: 0.0940 - val_loss: 0.0495 - lr: 1.0000e-04
# Epoch 2/10
# 165/165 [==============================] - 2263s 14s/step - loss: 0.0282 - val_loss: 0.0316 - lr: 1.0000e-04
# Epoch 3/10
# 165/165 [==============================] - 2183s 13s/step - loss: 0.0219 - val_loss: 0.0224 - lr: 1.0000e-04
# Epoch 4/10
# 165/165 [==============================] - 1607s 10s/step - loss: 0.0184 - val_loss: 0.0190 - lr: 1.0000e-04
# Epoch 5/10
# 165/165 [==============================] - 1601s 10s/step - loss: 0.0176 - val_loss: 0.0201 - lr: 1.0000e-04
# Epoch 6/10
# 165/165 [==============================] - 1980s 12s/step - loss: 0.0161 - val_loss: 0.0172 - lr: 1.0000e-04
# Epoch 7/10
# 165/165 [==============================] - 1404s 9s/step - loss: 0.0163 - val_loss: 0.0170 - lr: 1.0000e-04
# Epoch 8/10
# 165/165 [==============================] - 1294s 8s/step - loss: 0.0154 - val_loss: 0.0176 - lr: 1.0000e-04
# Epoch 9/10
# 165/165 [==============================] - 1267s 8s/step - loss: 0.0146 - val_loss: 0.0164 - lr: 1.0000e-04
# Epoch 10/10
# 165/165 [==============================] - 1247s 8s/step - loss: 0.0144 - val_loss: 0.0178 - lr: 1.0000e-04

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'])
# Out:
# ['loss', 'lr', 'val_loss']

# %%
plt.figure(figsize=(12,7))
_P = Trainingmodel.predict(X_val[:5])

plot_some(tf.transpose(X_val[:5], perm=[0, 3, 1, 2]),Y_val[:5],_P,pmax=99.5)
plt.suptitle('5 example validation patches\n'      
             'top row: input (source),  '          
             'middle row: target (ground truth),  '
             'bottom row: predicted from source')
# Out:
# Tensor("model/lambda_81/mul_1:0", shape=(None, 128, 128, 256), dtype=float32),2.0
# 1/1 [==============================] - 4s 4s/step
# Text(0.5, 0.98, '5 example validation patches\ntop row: input (source),  middle row: target (ground truth),  bottom row: predicted from source')

# %%
Trainingmodel.save(root_dir)
# Out:
# Tensor("model/lambda_81/mul_1:0", shape=(None, 128, 128, 256), dtype=float32),2.0
# Tensor("inputs:0", shape=(None, 128, 128, 256), dtype=float32),2.0
# Tensor("inputs:0", shape=(None, 128, 128, 256), dtype=float32),2.0
# Tensor("inputs:0", shape=(None, 128, 128, 256), dtype=float32),2.0
# Tensor("inputs:0", shape=(None, 128, 128, 256), dtype=float32),2.0
# INFO:tensorflow:Assets written to: /Users/vkapoor/Downloads/Microtubules/assets
# INFO:tensorflow:Assets written to: /Users/vkapoor/Downloads/Microtubules/assets
